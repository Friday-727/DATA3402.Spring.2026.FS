# %% [markdown]
# # Lab 4- Object Oriented Programming
#
# For all of the exercises below, make sure you provide tests of your solutions.

# %% [markdown]
# 1. Write a "counter" class that can be incremented up to a specified maximum value, will print an error if an attempt is made to increment beyond that value, and allows reseting the counter.

# %%
# One should still be able to change the maximum value parameter and the starting value

class counter:
    def __init__(self, start=0, max_value = 1000):
        self.counter = start
        self.max_value = max_value

    def increment(self, step = 1):
        if step <= 0:
            raise ValueError("Step must be nonnegative and greater than zero")
        current_count = self.counter + step
        
        if current_count >= self.max_value:
            print(f"This counter can only increment values up to {self.max_value}")
            self.counter = self.max_value
        else:
            self.counter = current_count
        print(f"Current count is: {self.counter}")
        return self.counter
   
    def reset_counter(self):
        if self.counter == 0:
            print("This counter is already at value: 0")
        else:
            self.counter = 0
            print("This counter has been properly reset")

# %%
dir(counter)
c = counter()
c.increment(2)
c.increment(5)
c.increment(1500)
# Out:
# Current count is: 2
# Current count is: 7
# This counter can only increment values up to 1000
# Current count is: 1000
# 1000

# %% [markdown]
# 2. Copy and paste your solution to question 1 and modify it so that all the data held by the counter is private. Implement functions to check the value of the counter, check the maximum value, and check if the counter is at the maximum.

# %% [markdown]
# What are data? --> All inputs of the class, in this class that would be the starting and maximum values
# How to implement private data? --> __data
# How to implement new functions? --> functions are types of methods defined within the class

# %%
# Modifying class to house private data

class counter:
    def __init__(self, start=0, max_value = 1000):

    #__ --> makes the data private (only able to be called by the class)
        self.__start = start
        self.__max_value = max_value
        self.counter = start

    # Increment would be considered a "setter" --> allows users to modify under certain conditions
    def increment(self, step = 1):
        if step <= 0:
            raise ValueError("Step must be nonnegative and greater than zero")
        current_count = self.counter + step
        
        if current_count >= self.__max_value:
            print(f"This counter can only increment values up to {self.__max_value}")
            self.counter = self.__max_value
        else:
            self.counter = current_count
        print(f"Current count is: {self.counter}")
        return self.counter

    # reset_counter would be considered a "getter" --> users can see the inner workings but wont be able to change it
    def reset_counter(self):
        if self.counter == 0:
            print("This counter is already at value: 0")
        else:
            self.counter = 0
            print("This counter has been properly reset")

# %%
# create a new instance 'a' of counter class that we can then alter using methods .increment() and .reset_counter()
a = counter()


#test out methods
a.increment(1)
a.increment(5)
a.reset_counter()
a.increment(1)
# Out:
# Current count is: 1
# Current count is: 6
# This counter has been properly reset
# Current count is: 1
# 1

# %%
# Implementing new functions: Check the value of the counter, Check the maximum value, Check if the counter is at the maximum

class counter:
    def __init__(self, start=0, max_value = 1000):

    #__ --> makes the data private (only able to be called by the class)
        self.__start = start
        self.__max_value = max_value
        self.counter = start

    # Increment would be considered a "setter" --> allows users to modify under certain conditions
    def increment(self, step = 1):
        if step <= 0:
            raise ValueError("Step must be nonnegative and greater than zero")
        current_count = self.counter + step
        
        if current_count >= self.__max_value:
            print(f"This counter can only increment values up to {self.__max_value}")
            self.counter = self.__max_value
        else:
            self.counter = current_count
        print(f"Current count is: {self.counter}")
        return self.counter

    # reset_counter would be considered a "getter" --> users can see the inner workings but wont be able to change it
    def reset_counter(self):
        if self.counter == 0:
            print("This counter is already at value: 0")
        else:
            self.counter = 0
            print("This counter has been properly reset")

    # check_value simply gives the user the current counter value, all we need to do is return self.counter, this is a "getter"
    
    def check_value(self):
        print(f"The value of the counter is at: {self.counter}")
        return self.counter

    def check_max_value(self):
        print(f"The value of maximum possible iterations is: {self.__max_value}")
        return self.__max_value

    def counter_at_max(self):
        return self.counter == self.__max_value

# %% [markdown]
# I got stuck here trying to figure out why my lastest implemented functions were not working. So I asked Copilot to check why the output was an error stating that there is no attribute check_value or check_max_value or counter_at_max even though running dir(counter) gave these attributes back.
#
# This might be due to creating an instance of the class for the previous question where the new methods check_value, check_max_value, and counter_at_max weren't yet defined --> which explains why 'no attribute' would make sense as an outcome.
#
# The only thing the AI added to my class was returning value 0 within the reset_counter function

# %%
class counter:
    def __init__(self, start=0, max_value=1000):
        # Double-underscore → name-mangled (private-ish)
        self.__start = start
        self.__max_value = max_value
        self.counter = start  # could also use self.value for clarity

    # Setter/mutator: increments by `step` with bounds checking
    def increment(self, step=1):
        if step <= 0:
            raise ValueError("Step must be positive (greater than zero)")
        current_count = self.counter + step
        
        if current_count >= self.__max_value:
            print(f"This counter can only increment values up to {self.__max_value}")
            self.counter = self.__max_value
        else:
            self.counter = current_count
        
        print(f"Current count is: {self.counter}")
        return self.counter  # returns the new value

    # Mutator: resets to zero
    def reset_counter(self):
        if self.counter == 0:
            print("This counter is already at value: 0")
            return 0
        else:
            self.counter = 0
            print("This counter has been properly reset")
            return 0

    # Getter: return the current counter value (not just print)
    def check_value(self):
        # print is fine for UX; return for programmatic use
        print(f"The value of the counter is: {self.counter}")
        return self.counter

    # Getter: return the max value
    def check_max_value(self):
        print(f"The maximum possible value is: {self.__max_value}")
        return self.__max_value

    # Predicate: is counter at max?
    def counter_at_max(self):
        return self.counter == self.__max_value

# %%
b = counter()

# %%
print(b.check_max_value())
print(b.check_value())
b.counter_at_max()
# Out:
# The maximum possible value is: 1000
# 1000
# The value of the counter is: 0
# 0
# False

# %%
dir(counter)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'check_max_value',
#  'check_value',
#  'counter_at_max',
#  'increment',
#  'reset_counter']

# %% [markdown]
# 3. Implement a class to represent a rectangle, holding the length, width, and $x$ and $y$ coordinates of a corner of the object. Implement functions that compute the area and perimeter of the rectangle. Make all data members private and provide accessors to retrieve values of data members.

# %%
class rectangle(Shape):
    def __init__(self, x, y, length, width):
        # (x, y) is bottom-left corner
        self._x = x
        self._y = y
        self.__length = length
        self.__width = width

    def area(self):
        return self.__length * self.__width

    def perimeter(self):
        return 2 * (self.__length + self.__width)

        return self.__length * 2 + self.__width * 2

# %%
rec1 = rectangle(0, 0, 5, 7)
rec1.area()
# Out:
# 35

# %%
rec1.perimeter()
# Out:
# 24

# %% [markdown]
# 4. Implement a class to represent a circle, holding the radius and $x$ and $y$ coordinates of center of the object. Implement functions that compute the area and perimeter of the rectangle. Make all data members private and privide accessors to retrieve values of data members.

# %%
class circle:
    def __init__(self, radius, x_coord, y_coord):
        self.__radius = radius
        self.__x_coord = x_coord
        self.__y_coord = y_coord

    #The methods below are accessors as they return the value
    def area(self):
        return 3.14*self.__radius**2

    def perimeter(self):
        return 6.28*self.__radius

# %%
cir1 = circle(5, 0, 0)
cir1.area()
# Out:
# 78.5

# %%
cir1.perimeter()
# Out:
# 31.400000000000002

# %% [markdown]
# 5. Implement a common base class for the classes implemented in 3 and 4 above which implements all common methods as not implemented functions (virtual). Re-implement your regtangle and circule classes to inherit from the base class and overload the functions accordingly.

# %%
class Shape:

    #virtual methods
    def __init__(self, x_coord, y_coord):
        self.__x_coord = x_coord
        self.__y_coord = y_coord
        initial_coord = [x_coord, y_coord]
        return initial_coord

class rectangle(Shape):
    def __init__(self, length, width):
        self.__length = length
        self.__width = width

    #The methods below are accessors as they return the value
    def area(self):
        return self.__length * self.__width

    def perimeter(self):
        return self.__length * 2 + self.__width * 2

class circle(Shape):
    def __init__(self, radius):
        self.__radius = radius
        
    #The methods below are accessors as they return the value
    def area(self):
        return 3.14*self.__radius**2

    def perimeter(self):
        return 6.28*self.__radius

# %%
rec2 = rectangle(4, 5)
rec2.area()
# Out:
# 20

# %%
rec2.perimeter()
# Out:
# 18

# %%
cir2 = circle(5)
cir2.area()
# Out:
# 78.5

# %%
cir2.perimeter()
# Out:
# 31.400000000000002

# %% [markdown]
# 6. Implement a triangle class analogous to the rectangle and circle in question 5.

# %%
class triangle(Shape):
    
    def __init__(self, x2_coord, y2_coord, x3_coord, y3_coord):
        self.__x2_coord = x2_coord
        self.__y2_coord = y2_coord
        self.__x3_coord = x3_coord
        self.__y3_coord = y3_coord

    def perimeter(self):
        line_1 = (((self.__x2_coord - 0)**2) + ((self.__y2_coord - 0)**2))**0.5
        line_2 = (((self.__x3_coord - 0)**2) + ((self.__y3_coord - 0)**2))**0.5
        line_3 = (((self.__x3_coord - self.__x2_coord)**2) + ((self.__y3_coord - self.__y2_coord)**2))**0.5

        return line_1 + line_2 + line_3

    def area(self):
        line_1 = (((self.__x2_coord - 0)**2) + ((self.__y2_coord - 0)**2))**0.5
        line_2 = (((self.__x3_coord - 0)**2) + ((self.__y3_coord - 0)**2))**0.5
        line_3 = (((self.__x3_coord - self.__x2_coord)**2) + ((self.__y3_coord - self.__y2_coord)**2))**0.5
        s = 0.5*(line_1 + line_2 + line_3) #semi-perimeter

        return (s*((s-line_1)*(s-line_2)*(s-line_3)))**0.5

# %%
tri1 = triangle(3, 1, 5, 2)
tri1.perimeter()
# Out:
# 10.783510444802673

# %%
tri1.area()
# Out:
# 0.5000000000000028

# %% [markdown]
# 7. Add a function to the object classes, including the base, that returns a list of up to 16 pairs of  $x$ and $y$ points on the parameter of the object.

# %%
class Shape:

    #virtual methods
    def __init__(self, x_coord, y_coord):
        self.__x_coord = x_coord
        self.__y_coord = y_coord
        initial_coord = [x_coord, y_coord]
        return initial_coord
    
    def even_spaced_points(self, *args, **kwargs): 
        raise NotImplementedError("Subclasses must implement even_spaced_points")

class rectangle(Shape):
    def __init__(self, x, y, length, width):
        # (x, y) is bottom-left corner
        self._x = x
        self._y = y
        self.__length = length
        self.__width = width

    def area(self):
        return self.__length * self.__width

    def perimeter(self):
        return 2 * (self.__length + self.__width)

    def even_spaced_points(self):
        # corners
        p1 = (self._x, self._y)
        p2 = (self._x + self.__length, self._y)
        p3 = (self._x, self._y + self.__width)
        p4 = (self._x + self.__length, self._y + self.__width)
        return [p1, p2, p3, p4]

import math

class circle(Shape):
    def __init__(self, radius, center = (0.0, 0.0)):
        self.__radius = radius
        self.__center = (center[0], center[1])
        
    #The methods below are accessors as they return the value
    def center(self):
        return self.__center
    
    def area(self):
        return 3.14*self.__radius**2

    def perimeter(self):
        return 6.28*self.__radius

    def even_spaced_points(self, n, offset = 0.0):
        if n < 0:
            raise ValueError("n must be positive")
        
        cx, cy = self.__center
        r = self.__radius
        points = []
        
        # Angle step
        step = 2 * 3.14 / n
        for k in range(n):
            theta = offset + k * step
            x = cx + r * math.cos(theta)
            y = cy + r * math.sin(theta)
            points.append((x, y))
        return points

class triangle(Shape):
    def __init__(self, x2_coord, y2_coord, x3_coord, y3_coord):
        self.__x2_coord = x2_coord
        self.__y2_coord = y2_coord
        self.__x3_coord = x3_coord
        self.__y3_coord = y3_coord

    def perimeter(self):
        line_1 = (((self.__x2_coord - 0)**2) + ((self.__y2_coord - 0)**2))**0.5
        line_2 = (((self.__x3_coord - 0)**2) + ((self.__y3_coord - 0)**2))**0.5
        line_3 = (((self.__x3_coord - self.__x2_coord)**2) + ((self.__y3_coord - self.__y2_coord)**2))**0.5

        return line_1 + line_2 + line_3

    def area(self):
        line_1 = (((self.__x2_coord - 0)**2) + ((self.__y2_coord - 0)**2))**0.5
        line_2 = (((self.__x3_coord - 0)**2) + ((self.__y3_coord - 0)**2))**0.5
        line_3 = (((self.__x3_coord - self.__x2_coord)**2) + ((self.__y3_coord - self.__y2_coord)**2))**0.5
        s = 0.5*(line_1 + line_2 + line_3) #semi-perimeter

        return (s*((s-line_1)*(s-line_2)*(s-line_3)))**0.5

    def even_spaced_points(self, x2_coord, y2_coord, x3_coord, y3_coord):
        points = []
        
        #first set of coordinates (origin, first point)
        point1 = (0, 0)
        points.append(point1)

        #second set of coordinates (second point)
        point2 = (self.__x2_coord, self.__y2_coord)
        points.append(point2)
        
        #third set of coordinates (third point)
        point3 = (self.__x3_coord, self.__y3_coord)
        points.append(point3)
           
        return points

# %%
rec3 = rectangle(5, 4)
rec3.perimeter()
# Out:
# 18

# %%
rec3.area()
# Out:
# 20

# %%
rec3.even_spaced_points(5, 4)
# Out:
# [(0, 0), (5, 0), (0, 4), (5, 4)]

# %%
tri2 = triangle(3, 7, 5, 3)
tri2.perimeter()
# Out:
# 17.918860955708787

# %%
tri2.area()
# Out:
# 12.999999999999993

# %%
tri2.even_spaced_points(3, 7, 5, 3)
# Out:
# [(0, 0), (3, 7), (5, 3)]

# %%
cir3 = circle(3)

# %%
cir3.even_spaced_points(n = 16)
# Out:
# [(3.0, 0.0),
#  (2.7718670984108162, 1.147498491828029),
#  (2.1221648075015995, 2.1204755433160978),
#  (1.1497054398018547, 2.770952435840432),
#  (0.00238898013219979, 2.999999048795504),
#  (-1.1452908161837203, 2.7727800032395695),
#  (-2.118784934460016, 2.123852725945296),
#  (-2.7700360161084374, 1.1519116587056915),
#  (-2.9999961951826184, 0.004777958749460485),
#  (-2.7736911497477856, -1.1430824142688958),
#  (-2.125539297576818, -2.1170929820054303),
#  (-1.154117147140496, -2.769117839795967),
#  (-0.007166934336844616, -2.999991439163154),
#  (1.1408732874839824, -2.7746005373576734),
#  (2.1153996870252683, -2.1272245213266503),
#  (2.7681979074852707, -1.1563219037076866)]

# %% [markdown]
# 8. Add a function to the object classes, including the base, that tests if a given set of $x$ and $y$ coordinates are inside of the object. You'll have to think through how to determine if a set of coordinates are inside an object for each object type.

# %%
class Shape:

    #virtual methods
    def __init__(self, x_coord, y_coord):
        self.__x_coord = x_coord
        self.__y_coord = y_coord
        initial_coord = [x_coord, y_coord]
        return initial_coord
    
    def contains_point(self, x, y): 
        raise NotImplementedError("Subclasses must implement contains_point")

    def even_spaced_points(self, *args, **kwargs): 
        raise NotImplementedError("Subclasses must implement even_spaced_points")

    
class rectangle(Shape):
    def __init__(self, x, y, length, width):
        # (x, y) is bottom-left corner
        self._x = x
        self._y = y
        self.__length = length
        self.__width = width

    def area(self):
        return self.__length * self.__width

    def perimeter(self):
        return 2 * (self.__length + self.__width)

    def even_spaced_points(self):
        # corners
        p1 = (self._x, self._y)
        p2 = (self._x + self.__length, self._y)
        p3 = (self._x, self._y + self.__width)
        p4 = (self._x + self.__length, self._y + self.__width)
        return [p1, p2, p3, p4]

    def contains_point(self, x, y):
        return (self._x <= x <= self._x + self.__length and
                self._y <= y <= self._y + self.__width)


import math

class circle(Shape):
    def __init__(self, radius, center=(0.0, 0.0)):
        self.__radius = radius
        self.__center = (center[0], center[1])
        
    # Accessors
    def center(self):
        return self.__center
    
    def area(self):
        return 3.14 * self.__radius**2

    def perimeter(self):
        return 6.28 * self.__radius

    def even_spaced_points(self, n, offset=0.0):
        if n < 0:
            raise ValueError("n must be positive")
        
        cx, cy = self.__center
        r = self.__radius
        points = []
        
        step = 2 * 3.14 / n
        for k in range(n):
            theta = offset + k * step
            x = cx + r * math.cos(theta)
            y = cy + r * math.sin(theta)
            points.append((x, y))
        return points

    def contains_point(self, x, y):
        #returns true if selected x and y are within or on the border of the shape
        cx, cy = self.__center
        dx = x - cx
        dy = y - cy
        return dx*dx + dy*dy <= self.__radius * self.__radius

class triangle(Shape):
    def __init__(self, x2_coord, y2_coord, x3_coord, y3_coord):
        self.__x2_coord = x2_coord
        self.__y2_coord = y2_coord
        self.__x3_coord = x3_coord
        self.__y3_coord = y3_coord

    def perimeter(self):
        line_1 = (((self.__x2_coord - 0)**2) + ((self.__y2_coord - 0)**2))**0.5
        line_2 = (((self.__x3_coord - 0)**2) + ((self.__y3_coord - 0)**2))**0.5
        line_3 = (((self.__x3_coord - self.__x2_coord)**2) + ((self.__y3_coord - self.__y2_coord)**2))**0.5

        return line_1 + line_2 + line_3

    def area(self):
        line_1 = (((self.__x2_coord - 0)**2) + ((self.__y2_coord - 0)**2))**0.5
        line_2 = (((self.__x3_coord - 0)**2) + ((self.__y3_coord - 0)**2))**0.5
        line_3 = (((self.__x3_coord - self.__x2_coord)**2) + ((self.__y3_coord - self.__y2_coord)**2))**0.5
        s = 0.5*(line_1 + line_2 + line_3) #semi-perimeter

        return (s*((s-line_1)*(s-line_2)*(s-line_3)))**0.5

    def even_spaced_points(self):
        points = []
        
        #first set of coordinates (origin, first point)
        points.append((0,0))

        #second set of coordinates (second point)
        points.append((self.__x2_coord, self.__y2_coord))
        
        #third set of coordinates (third point)
        points.append((self.__x3_coord, self.__y3_coord))
           
        return points

    def contains_point(self, x, y): 
        # Triangle vertices 
        p1 = (0, 0) 
        p2 = (self.__x2_coord, self.__y2_coord) 
        p3 = (self.__x3_coord, self.__y3_coord) 
        p = (x, y) 
        
        # Compute triangle area 
        def area(a, b, c): 
            (x1, y1), (x2, y2), (x3, y3) = a, b, c 
            return abs(x1*(y2 - y3) + x2*(y3 - y1) + x3*(y1 - y2)) / 2.0 
            
        # Total area 
        A = area(p1, p2, p3)

        # Areas with point P 
        A1 = area(p, p2, p3) 
        A2 = area(p1, p, p3) 
        A3 = area(p1, p2, p) 
        
        return abs((A1 + A2 + A3) - A) < 1e-9

# %% [markdown]
# 9. Add a function in the base class of the object classes that returns true/false testing that the object overlaps with another object.

# %%
class Shape:

    #virtual methods
    def __init__(self, x_coord, y_coord):
        self.__x_coord = x_coord
        self.__y_coord = y_coord
        initial_coord = [x_coord, y_coord]
        return initial_coord
    
    def contains_point(self, x, y): 
        raise NotImplementedError("Subclasses must implement contains_point")
    
    def even_spaced_points(self, *args, **kwargs): 
        raise NotImplementedError("Subclasses must implement even_spaced_points")

    def overlaps(self, other):
        # 1. Check if any 'self' points lie inside the 'other' shape 
        for (x, y) in self.even_spaced_points(): 
            if other.contains_point(x, y): 
                return True 
        # 2. Check if any of the 'other' points lie inside 'self'
        for (x, y) in other.even_spaced_points(): 
            if self.contains_point(x, y): 
                return True 
        return False

class rectangle(Shape):
    def __init__(self, x, y, length, width):
        # (x, y) is bottom-left corner
        self._x = x
        self._y = y
        self.__length = length
        self.__width = width

    def area(self):
        return self.__length * self.__width

    def perimeter(self):
        return 2 * (self.__length + self.__width)

    def even_spaced_points(self):
        # corners
        p1 = (self._x, self._y)
        p2 = (self._x + self.__length, self._y)
        p3 = (self._x, self._y + self.__width)
        p4 = (self._x + self.__length, self._y + self.__width)
        return [p1, p2, p3, p4]

    def contains_point(self, x, y):
        return (self._x <= x <= self._x + self.__length and
                self._y <= y <= self._y + self.__width)


import math

class circle(Shape):
    def __init__(self, radius, center=(0.0, 0.0)):
        self.__radius = radius
        self.__center = (center[0], center[1])
        
    # Accessors
    def center(self):
        return self.__center
    
    def area(self):
        return 3.14 * self.__radius**2

    def perimeter(self):
        return 6.28 * self.__radius

    def even_spaced_points(self, n, offset=0.0):
        if n < 0:
            raise ValueError("n must be positive")
        
        cx, cy = self.__center
        r = self.__radius
        points = []
        
        step = 2 * 3.14 / n
        for k in range(n):
            theta = offset + k * step
            x = cx + r * math.cos(theta)
            y = cy + r * math.sin(theta)
            points.append((x, y))
        return points

    def contains_point(self, x, y):
        #returns true if selected x and y are within or on the border of the shape
        cx, cy = self.__center
        dx = x - cx
        dy = y - cy
        return dx*dx + dy*dy <= self.__radius * self.__radius

class triangle(Shape):
    def __init__(self, x2_coord, y2_coord, x3_coord, y3_coord):
        self.__x2_coord = x2_coord
        self.__y2_coord = y2_coord
        self.__x3_coord = x3_coord
        self.__y3_coord = y3_coord

    def perimeter(self):
        line_1 = (((self.__x2_coord - 0)**2) + ((self.__y2_coord - 0)**2))**0.5
        line_2 = (((self.__x3_coord - 0)**2) + ((self.__y3_coord - 0)**2))**0.5
        line_3 = (((self.__x3_coord - self.__x2_coord)**2) + ((self.__y3_coord - self.__y2_coord)**2))**0.5

        return line_1 + line_2 + line_3

    def area(self):
        line_1 = (((self.__x2_coord - 0)**2) + ((self.__y2_coord - 0)**2))**0.5
        line_2 = (((self.__x3_coord - 0)**2) + ((self.__y3_coord - 0)**2))**0.5
        line_3 = (((self.__x3_coord - self.__x2_coord)**2) + ((self.__y3_coord - self.__y2_coord)**2))**0.5
        s = 0.5*(line_1 + line_2 + line_3) #semi-perimeter

        return (s*((s-line_1)*(s-line_2)*(s-line_3)))**0.5

    def even_spaced_points(self):
        points = []
        
        #first set of coordinates (origin, first point)
        points.append((0,0))

        #second set of coordinates (second point)
        points.append((self.__x2_coord, self.__y2_coord))
        
        #third set of coordinates (third point)
        points.append((self.__x3_coord, self.__y3_coord))
           
        return points

    def contains_point(self, x, y): 
        # Triangle vertices 
        p1 = (0, 0) 
        p2 = (self.__x2_coord, self.__y2_coord) 
        p3 = (self.__x3_coord, self.__y3_coord) 
        p = (x, y) 
        
        # Compute triangle area 
        def area(a, b, c): 
            (x1, y1), (x2, y2), (x3, y3) = a, b, c 
            return abs(x1*(y2 - y3) + x2*(y3 - y1) + x3*(y1 - y2)) / 2.0 
            
        # Total area 
        A = area(p1, p2, p3)

        # Areas with point P 
        A1 = area(p, p2, p3) 
        A2 = area(p1, p, p3) 
        A3 = area(p1, p2, p) 
        
        return abs((A1 + A2 + A3) - A) < 1e-9

# %%
rec5 = rectangle(0, 0, 5, 5)
rec5.contains_point(-1, 4)
# Out:
# False

# %%
cir5 = circle(5)
cir5.contains_point(4,3)
# Out:
# True

# %%
tri4 = triangle(5, 2, 2, 5)
tri4.even_spaced_points()
# Out:
# [(0, 0), (5, 2), (2, 5)]

# %%
tri4.overlaps(cir5)
# Out:
# True

# %%
rec6 = rectangle(3,3,2,2)
rec7 = rectangle(0,0,2,2)

# %%
rec6.overlaps(rec7)
# Out:
# False

# %%
cir5.area()
# Out:
# 78.5

# %% [markdown]
# ###CONTINUE HERE###
#
# 10. Copy the `Canvas` class from lecture to in a python file creating a `paint` module. Copy your classes from above into the module and implement paint functions. Implement a `CompoundShape` class. Create a simple drawing demonstrating that all of your classes are working.

# %%
#implementing a paint module

class Canvas:
    def __init__(self, width, height):
        self.width = width
        self.height = height
        # Empty canvas is a matrix with element being the "space" character
        self.data = [[' '] * width for i in range(height)]

    def set_pixel(self, row, col, char='*'):
        self.data[row][col] = char

    def get_pixel(self, row, col):
        return self.data[row][col]
    
    def clear_canvas(self):
        self.data = [[' '] * self.width for i in range(self.height)]
    
    def v_line(self, x, y, w, **kargs):
        for i in range(x,x+w):
            self.set_pixel(i,y, **kargs)

    def h_line(self, x, y, h, **kargs):
        for i in range(y,y+h):
            self.set_pixel(x,i, **kargs)
            
    def line(self, x1, y1, x2, y2, **kargs):
        slope = (y2-y1) / (x2-x1)
        for y in range(y1,y2):
            x= int(slope * y)
            self.set_pixel(x,y, **kargs)

    def display(self):
        print("\n".join(["".join(row) for row in self.data]))

# %%
c1=Canvas(40,40)
c1.v_line(1,1,5,char='|')
c1.h_line(3,3,4)
c1.line(4,4,30,20)
c1.display()
# Out:
#
#  |
#  |  *
#  | ****
#  |     **
#  |       *
#           **
#             *
#              **
#                **
#                  *
#                   **

# %% [markdown]
# 11. Create a `RasterDrawing` class. Demonstrate that you can create a drawing made of several shapes, paint the drawing, modify the drawing, and paint it again.

# %% [markdown]
# 12. Implement the ability to load/save raster drawings and demonstate that your method works. One way to implement this ability:
#
#    * Overload `__repr__` functions of all objects to return strings of the python code that would construct the object.
#
#    * In the save method of raster drawing class, store the representations into the file.
#    * Write a loader function that reads the file and uses `eval` to instantiate the object.
#
# For example:

# %%
class foo:
    def __init__(self,a,b=None):
        self.a=a
        self.b=b
        
    def __repr__(self):
        return "foo("+repr(self.a)+","+repr(self.b)+")"
    
    def save(self,filename):
        f=open(filename,"w")
        f.write(self.__repr__())
        f.close()
        
   
def foo_loader(filename):
    f=open(filename,"r")
    tmp=eval(f.read())
    f.close()
    return tmp

# %%
# Test
print(repr(foo(1,"hello")))
# Out:
# foo(1,'hello')

# %%
# Create an object and save it
ff=foo(1,"hello")
ff.save("Test.foo")

# %%
# Check contents of the saved file
# !cat Test.foo
# Out:
# foo(1,'hello')

# %%
# Load the object
ff_reloaded=foo_loader("Test.foo")
ff_reloaded
# Out:
# foo(1,'hello')
